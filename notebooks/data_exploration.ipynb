# %% [markdown]
# # Hospital Capacity Analysis – Data Exploration
#
# Author: David Saridakis
# Project: hospital-capacity-analysis
#
# ## Description
# This notebook performs the initial exploration of the Spanish hospital dataset
# published by the Ministerio de Sanidad.
#
# The purpose of this notebook is to:
#
# - Load the raw dataset
# - Inspect its structure and data types
# - Identify potential data quality issues
# - Determine cleaning steps required before database ingestion
#
# The cleaned dataset will later be stored in a MySQL database and used for SQL analysis and dashboard visualization in Looker Studio.
#
# ## Dataset Source
# Catálogo Nacional de Hospitales – Spanish Ministry of Health
#
# ## Output
# Insights from this exploration will inform the data cleaning process implemented in the next stage of the project.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Load Raw Dataset

# %%
# Load and inspect the dataset 
df = pd.read_excel("../data/raw/hospitales_spain_raw.xlsx")
df.head()
# Out:
#           CCN  CODCNH                           Nombre Centro  \
# 0  1531000730  310121                 Hospital García Orcoyen
# 1  1531000738  310076  Clínica Arcángel San Miguel - Pamplona
# 2  1531000736  310057        Clínica Psiquiátrica Padre Menni
# 3  1531000733  310060          Clínica Universidad de Navarra
# 4  1531000737  310044               Hospital San Juan de Dios
#
#                    Dirección   Teléfono  Cód. Municipio        Municipio  \
# 0     Calle Santa Soria 22 -  848435000          310977  Estella-Lizarra
# 1     Calle Beloso Alto 32 -  948296000          312016   Pamplona/Iruña
# 2  Calle Joaquín Beunza 45 -  948140611          312016   Pamplona/Iruña
# 3        Avenida Pio Si 36 -  948255400          312016   Pamplona/Iruña
# 4      Calle Beloso Alto 3 -  948231800          312016   Pamplona/Iruña
#
#    Cód. Provincia Provincia  Cód. CCAA  ... CAMAS  Cód. Clase de Centro  \
# 0              31   Navarra         15  ...   108                   C11
# ...

# %% [markdown]
# ## 3. Inspect Dataset Structure

# %%
df.shape
df.columns

df.info()
df.describe()

# Top 10 largest hospitals by capacity
df['CAMAS'].sort_values(ascending=False).head(10)

# Number of hospitals: Private v Public v Other
df['Dependencia Funcional'].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CCN                    840 non-null    int64
#  1   CODCNH                 840 non-null    int64
#  2   Nombre Centro          840 non-null    str
#  3   Dirección              840 non-null    str
#  4   Teléfono               840 non-null    str
#  5   Cód. Municipio         840 non-null    int64
#  6   Municipio              840 non-null    str
#  7   Cód. Provincia         840 non-null    int64
#  8   Provincia              840 non-null    str
#  9   Cód. CCAA              840 non-null    int64
#  10  CCAA                   840 non-null    str
#  11  Código Postal          840 non-null    int64
#  12  CAMAS                  840 non-null    int64
#  13  Cód. Clase de Centro   840 non-null    str
#  14  Clase de Centro        840 non-null    str
# ...

# %% [markdown]
# ## 4. Identify Cleaning Requirements

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Nombre del Complejo      724
# CODIDCOM                 724
# Email                    241
# Nombre Centro              0
# CCN                        0
# CODCNH                     0
# Cód. Municipio             0
# Teléfono                   0
# Dirección                  0
# Municipio                  0
# CCAA                       0
# Cód. Provincia             0
# Provincia                  0
# Cód. CCAA                  0
# Cód. Clase de Centro       0
# CAMAS                      0
# Código Postal              0
# Clase de Centro            0
# Forma parte Complejo       0
# Dependencia Funcional      0
# Cód. Dep. Funcional        0
# ALTA                       0
# dtype: int64
